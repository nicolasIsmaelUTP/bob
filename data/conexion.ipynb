# %% [markdown]
# # Connection

# %%
# Cargar variables de entorno desde .env
from supabase import create_client, Client
from dotenv import load_dotenv
import os

load_dotenv()

# Obtener credenciales
url: str = os.getenv("SUPABASE_URL")
key: str = os.getenv("SUPABASE_SERVICE_ROLE")

# Crear cliente Supabase
supabase: Client = create_client(url, key)

# %%
res = supabase.table("leads")\
    .select("id, full_name, phone, email, created_at")\
    .order("created_at", desc=True)\
    .limit(5)\
    .execute()

for lead in res.data:
    print(f"{lead['id']} | {lead['full_name']} | {lead['phone']} | {lead['email']} | {lead['created_at']}")
# Out:
# ea8acef1-9aa4-46e9-84a5-90b07985e4df | Practis Dibujitos | 987987987 | practiwowxd@gmail.com | 2025-11-05T05:28:52.186312+00:00

# %% [markdown]
# # Probando entrenamiento

# %%
import json
import pandas as pd
import numpy as np
from sklearn.model_selection import train_test_split
from sklearn.preprocessing import LabelEncoder, StandardScaler
from sklearn.utils.class_weight import compute_sample_weight
from sklearn.metrics import classification_report, confusion_matrix
from xgboost import XGBClassifier, plot_importance
import joblib
import matplotlib.pyplot as plt
import re

# %%
# === Cargar datasets ===
df_msg = pd.read_json('dataset_mensajes.json')
df_lead = pd.read_json('dataset_leads.json')
print('Mensajes:', df_msg.shape, 'Leads:', df_lead.shape)
# Out:
# Mensajes: (450, 9) Leads: (10, 10)

# %%
df_msg
# Out:
#      message_id   lead_id                                            mensaje  \
# 0             1  LEAD-001      Quiero ofertar en varios lotes, cómo procedo?
# 1             2  LEAD-002                       Solo estoy revisando qué hay
# 2             3  LEAD-003                             Aún no estoy decidido.
# 3             4  LEAD-004                Quisiera saber más sobre los lotes.
# 4             5  LEAD-005  Confirmen mi participación en la subasta de ca...
# ..          ...       ...                                                ...
# 445         446  LEAD-446           ¿Cómo se realiza el pago de la garantía?
# 446         447  LEAD-447                          Todavía no estoy decidido
# 447         448  LEAD-448                      Estoy revisando mis opciones.
# 448         449  LEAD-449                        ¿Puedo revisar los precios?
# 449         450  LEAD-450  Confirmen por favor que recibieron mi transfer...
#
# ...

# %% [markdown]
# ## Modelo 1: Scoring messages

# %% [markdown]
# ## Probando Modelo 1

# %%
from test_message import predecir_intencion
   
resultado = predecir_intencion("Ya hice el pago, confirmen por favor")
print(resultado['intencion'])  # 'alta'
print(resultado['probabilidades'])  # {'alta': 0.99, ...}
